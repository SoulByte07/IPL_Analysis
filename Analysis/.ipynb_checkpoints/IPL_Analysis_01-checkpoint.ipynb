# %% [markdown]
# # 🏏IPL Data Analysis

# %% [markdown]
# Welcome to this mini IPL analysis project!
# In this notebook, we’ll explore various trends in the Indian Premier League (IPL) using real match data to gain insights and understand how to approach a real-world machine learning project with data analysis.

# %% [markdown]
# ### import libraries

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### 🔍 Dataset Overview
#
# We are working with two datasets:
#
#     matches.csv – contains match-level data like season, teams, winner, toss decision, etc.
#
#     deliveries.csv – contains ball-by-ball delivery data (not deeply explored in this phase).
#
# We’ll perform data analysis and visualization using pandas, matplotlib, and seaborn.

# %%
matches = pd.read_csv('../Datasets/Cleaned Datasets/cleaned_matches.csv')
deliveries = pd.read_csv('../Datasets/Cleaned Datasets/cleaned_deliveries.csv')

# print the first 5 rows of the loaded data
print(matches.head())
print(deliveries.head())
# Out:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 2  335984  2007/08       Delhi  2008-04-19     League     MF Maharoof
# 3  335985  2007/08      Mumbai  2008-04-20     League      MV Boucher
# 4  335986  2007/08     Kolkata  2008-04-20     League       DJ Hussey
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                            Feroz Shah Kotla               Delhi Capitals
# 3                            Wankhede Stadium               Mumbai Indians
# 4                                Eden Gardens        Kolkata Knight Riders
#
#                          team2                  toss_winner toss_decision  \
# ...

# %% [markdown]
# ### 🏆 Top 5 Teams With Most Wins
#
# Let’s begin by identifying the most successful teams in IPL history based on the total number of matches won.

# %%
top_teams= matches['winner'].value_counts().head(5)

#plot 1
sns.set(style="whitegrid")
plt.figure(figsize=(8, 5)) 
sns.barplot(x=top_teams.values,y=top_teams.index,hue=top_teams.index,palette='viridis',legend=False)
plt.title('top 5 teams(winners)')
plt.xlabel('no of wins')
plt.ylabel('teams')
plt.tight_layout()
plt.show()
plt.clf()

# %% [markdown]
# ### Insight:
# This plot shows the top 5 teams with the highest number of match wins in IPL. These teams have consistently performed well across seasons.

# %% [markdown]
# ### 🧍‍♂️ Top 10 Players of the Match
#
# Who are the most impactful players in the IPL? Let’s analyze the players who received the most "Player of the Match" awards.

# %%
top_players = matches['player_of_match'].value_counts().head(10)

# Plot 2
sns.barplot(x=top_players.values, y=top_players.index, hue=top_players.index,palette="magma")
plt.title("Top 10 Players of the Match")
plt.xlabel("Number of Awards")
plt.ylabel("Player")
plt.show()
plt.clf()

# %% [markdown]
# ### Insight:
# These players have delivered outstanding performances in individual matches and have been game changers for their teams.

# %% [markdown]
# ### 🎲 Does Winning the Toss Matter?
#
# Let's analyze whether winning the toss increases the chances of winning the match.

# %%
# Create a new column
matches['toss_match_win'] = matches['toss_winner'] == matches['winner']

# Count how often toss winner also won the match
toss_result = matches['toss_match_win'].value_counts()

# Plot 3
sns.barplot(x=toss_result.index, y=toss_result.values,hue=toss_result.index, palette="Set2")
plt.xticks([0, 1], ['Lost Match', 'Won Match'])
plt.title("Does Toss Winner Also Win Match?")
plt.ylabel("Number of Matches")
plt.show()
plt.clf()

# %% [markdown]
# ### Insight:
# From this chart, we observe whether toss winners have an actual advantage in match outcomes.

# %% [markdown]
# ### 🏟️ Most Popular Venues
#
# Where are most IPL matches played? Let’s find out the top stadiums that host the maximum matches.

# %%
venue_counts = matches['venue'].value_counts().head(10)

#plot 4
sns.barplot(y=venue_counts.index, x=venue_counts.values,hue=venue_counts.index, palette="cubehelix")
plt.title("Top 10 Most Used Venues")
plt.xlabel("No. of Matches")
plt.ylabel("Venue")
plt.show()
plt.clf()

# %% [markdown]
# ### Insight:
# These venues are IPL favorites, possibly due to capacity, facilities, or regional fanbase.

# %% [markdown]
# ### 🧢 Toss Decision: Bat or Field?
#
# What’s the usual choice after winning the toss—bat first or field first?

# %%
#recult type counts
result_type=matches['toss_decision'].value_counts()

# Pie chart
plt.pie(result_type, labels=result_type.index, autopct='%1.1f%%', colors=['#FFDDC1', '#B5EAD7'])
plt.title("Match Wins: Batting First vs Chasing")
plt.show()
plt.clf()

# %% [markdown]
# ### Insight:
# The chart shows the common strategy teams follow after winning the toss—whether they choose to set a target or chase.

# %% [markdown]
# ### 📅 Matches Played Per Season
#
# Let’s see how the IPL has grown over time by checking the number of matches played each season.

# %%
matches_per_year = matches['season'].value_counts().sort_index()

#plot 5
sns.lineplot(x=matches_per_year.index, y=matches_per_year.values, marker='o')
plt.title("IPL Matches Per Season")
plt.xlabel("Season")
plt.ylabel("Number of Matches")
plt.show()
plt.clf()

# %% [markdown]
# ### Insight:
# This visualization shows trends in how the tournament expanded or adjusted across different seasons.

# %% [markdown]
# ### 🥇 Most Successful Team Per Season
#
# Let’s find the top team for each season based on the number of matches won.

# %%
season_winner = matches.groupby(['season', 'winner']).size().reset_index(name='wins')

# Get max win team per season
top_per_season = season_winner.loc[season_winner.groupby('season')['wins'].idxmax()]

# Display as table
print(top_per_season[['season', 'winner', 'wins']])
# Out:
#       season                 winner  wins
# 5    2007/08       Rajasthan Royals    13
# 9       2009         Delhi Capitals    10
# 20   2009/10         Mumbai Indians    11
# 24      2011    Chennai Super Kings    11
# 37      2012  Kolkata Knight Riders    12
# 47      2013         Mumbai Indians    13
# 54      2014        Kings XI Punjab    12
# 60      2015    Chennai Super Kings    10
# 75      2016    Sunrisers Hyderabad    11
# 80      2017         Mumbai Indians    12
# 84      2018    Chennai Super Kings    11
# 96      2019         Mumbai Indians    11
# 104  2020/21         Mumbai Indians    11
# 108     2021    Chennai Super Kings    11
# 118     2022         Gujarat Titans    12
# 128     2023         Gujarat Titans    11
# 139     2024  Kolkata Knight Riders    11

# %% [markdown]
# ### Insight:
# This gives a season-by-season breakdown of the most dominant team. It's useful to understand shifts in team performance.

# %% [markdown]
# ## ✅ Summary
#
# ### This mini-project helped us:
#
# - Clean and load real-world IPL data
# - Apply `groupby` and `value_counts` to find patterns
# - Use visualization for storytelling
# - Gain insights into team and player performances
#
# ### 👉 This lays the foundation for building predictive models in future phases like:
#
# - Match outcome prediction
# - Player performance prediction

# %% [markdown]
# ML prediction will conntinue on IPL_Analysis_02.ipynb
